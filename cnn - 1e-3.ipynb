# %%
import h5py as h
import numpy as np

# %% [markdown]
# Cargamos las imágenes generadas por el código `delphes_gans`

# %%
f = h.File("new.h5", 'r')
images = np.vstack([f["qcd/images"][:], f["wprime/images"][:]])
labels = np.hstack([f["qcd/labels"][:], f["wprime/labels"][:]])

# %% [markdown]
# Acomodamos la información y separamos en datos de entrenamiento y de validación.

# %%
from sklearn.model_selection import train_test_split
from tensorflow.keras.utils import to_categorical

images = np.reshape(images, [-1, 25, 25, 1])
labels = to_categorical(labels)
x_train, x_test, y_train, y_test = train_test_split(images, labels, test_size=0.2, shuffle=True)

# %% [markdown]
# Las siguientes funciones ayudan a crear la red más flexible y rápida. Cada una de ellas define una nueva **capa** de la red. Entendemos como capa a cada operación del flujo de datos en la red.

# %%
def conv_layer(input, num_input_channels, filter_size, num_filters, name):
    with tf.variable_scope(name) as scope:
        shape   = [filter_size, filter_size, num_input_channels, num_filters]
        weights = tf.Variable(tf.truncated_normal(shape, stddev=0.05))
        biases  = tf.Variable(tf.constant(0.05, shape=[num_filters]))
        layer   = tf.nn.conv2d(input=input, filter=weights, strides=[1, 1, 1, 1], padding='SAME')
        layer += biases
        
        return layer, weights
    
def pool_layer(input, name):
    with tf.variable_scope(name) as scope:
        layer = tf.nn.max_pool(value=input, ksize=[1, 2, 2, 1], strides=[1, 2, 2, 1], padding='SAME')
        
        return layer

def relu_layer(input, name):    
    with tf.variable_scope(name) as scope:
        layer = tf.nn.relu(input)
        
        return layer
    
def fully_connected_layer(input, num_inputs, num_outputs, name):
    with tf.variable_scope(name) as scope:
        weights = tf.Variable(tf.truncated_normal([num_inputs, num_outputs], stddev=0.05))
        biases  = tf.Variable(tf.constant(0.05, shape=[num_outputs]))
        layer   = tf.matmul(input, weights) + biases
        
        return layer

# %% [markdown]
# Definimos la red

# %%
import tensorflow as tf

X = tf.placeholder(tf.float32, shape=[None, 25, 25, 1], name='X')
Y = tf.placeholder(tf.float32, shape=[None, 2], name='Y')

conv1, weights1 = conv_layer(X, num_input_channels=1, filter_size=5, num_filters=6, name="conv1")
pool1 = pool_layer(conv1, "pool1")
relu1 = relu_layer(pool1, "relu1")

conv2, weights2 = conv_layer(relu1, num_input_channels=6, filter_size=5, num_filters=16, name="conv2")
pool2 = pool_layer(conv2, "pool2")
relu2 = relu_layer(pool2, "relu2")

num_features = relu2.get_shape()[1:].num_elements()
layer_flat = tf.reshape(relu2, [-1, num_features])

layer_fc1 = fully_connected_layer(layer_flat, num_inputs=num_features, num_outputs=128, name="fc1")
layer_relu3 = relu_layer(layer_fc1, name="relu3")
layer_fc2 = fully_connected_layer(layer_relu3, num_inputs=128, num_outputs=2, name="fc2")

with tf.variable_scope("Softmax"):
    y_pred = tf.nn.softmax(layer_fc2)
    y_pred_cls = tf.argmax(y_pred, axis=1)

with tf.name_scope("cross_ent"):
    cross_entropy = tf.nn.softmax_cross_entropy_with_logits_v2(logits=layer_fc2, labels=Y)
    cost = tf.reduce_mean(cross_entropy)

with tf.name_scope("optimizer"):
    optimizer = tf.train.AdamOptimizer(learning_rate=1e-3).minimize(cost)

with tf.name_scope("accuracy"):
    correct_prediction = tf.equal(y_pred_cls, tf.argmax(Y, axis=1))
    accuracy = tf.reduce_mean(tf.cast(correct_prediction, tf.float32))

writer = tf.summary.FileWriter("C:/Usuarios/Olga/CNN_JetImages/1e-3")
writer1 = tf.summary.FileWriter("C:/Usuarios/Olga/CNN_JetImages/1e-3")

tf.summary.scalar('loss', cost)
tf.summary.scalar('accuracy', accuracy)
merged_summary = tf.summary.merge_all()

# %%
num_epochs = 300

ep = np.array([])
acc = np.array([])
loss = np.array([])

with tf.Session() as sess:
    sess.run(tf.global_variables_initializer())
    writer.add_graph(sess.graph)

    for epoch in range(num_epochs):
        feed_dict_train = {X: x_train, Y: y_train}
        sess.run(optimizer, feed_dict=feed_dict_train)
        
        if epoch%5==0:
            train_summ, train_acc, train_loss = sess.run([merged_summary, accuracy, cost], feed_dict=feed_dict_train)
            val_summ, val_acc, val_loss = sess.run([merged_summary, accuracy, cost], feed_dict={X: x_test, Y: y_test})
            writer.add_summary(train_summ, epoch)
            writer1.add_summary(val_summ, epoch)
        
            saver = tf.train.Saver(max_to_keep=15)
            saver.save(sess,"cnn/epoch{:04}.ckpt".format((epoch)))
        
            ep = np.append(ep,epoch)
            acc = np.append(acc,train_acc)
            loss = np.append(loss,train_loss)

            
            print(f"Epoch {str(epoch)} completed")
            print ("\t- Training Accuracy:\t{}".format(train_acc))
            print ("\t- Validation Accuracy:\t{}".format(val_acc))
            print ("\t- Validation Loss:\t{}".format(val_loss))
# Out:
# Epoch 0 completed
# 	- Training Accuracy:	0.6838144063949585
# 	- Validation Accuracy:	0.6910476088523865
# 	- Validation Loss:	0.6264092922210693
# Epoch 5 completed
# 	- Training Accuracy:	0.7952748537063599
# 	- Validation Accuracy:	0.803428590297699
# 	- Validation Loss:	0.49655282497406006
# Epoch 10 completed
# 	- Training Accuracy:	0.8089930415153503
# 	- Validation Accuracy:	0.8148571252822876
# 	- Validation Loss:	0.4486158788204193
# Epoch 15 completed
# 	- Training Accuracy:	0.8201391100883484
# 	- Validation Accuracy:	0.8255237936973572
# 	- Validation Loss:	0.4218482971191406
# Epoch 20 completed
# 	- Training Accuracy:	0.8383347392082214
# 	- Validation Accuracy:	0.8487619161605835
# 	- Validation Loss:	0.3828578591346741
# Epoch 25 completed
# 	- Training Accuracy:	0.8559588193893433
# 	- Validation Accuracy:	0.8552380800247192
# 	- Validation Loss:	0.35661083459854126
# Epoch 30 completed
# 	- Training Accuracy:	0.8715823292732239
# 	- Validation Accuracy:	0.864380955696106
# 	- Validation Loss:	0.3297998011112213
# Epoch 35 completed
# 	- Training Accuracy:	0.8805372714996338
# 	- Validation Accuracy:	0.8788571357727051
# 	- Validation Loss:	0.3057343065738678
# Epoch 40 completed
# 	- Training Accuracy:	0.8934933543205261
# 	- Validation Accuracy:	0.8914285898208618
# 	- Validation Loss:	0.2824550271034241
# Epoch 45 completed
# 	- Training Accuracy:	0.9054968357086182
# 	- Validation Accuracy:	0.9017142653465271
# 	- Validation Loss:	0.26607105135917664
# Epoch 50 completed
# 	- Training Accuracy:	0.9154996871948242
# 	- Validation Accuracy:	0.9062857031822205
# 	- Validation Loss:	0.2490977793931961
# Epoch 55 completed
# 	- Training Accuracy:	0.9237877726554871
# 	- Validation Accuracy:	0.9139047861099243
# 	- Validation Loss:	0.23549772799015045
# Epoch 60 completed
# 	- Training Accuracy:	0.9306468367576599
# 	- Validation Accuracy:	0.9196190237998962
# 	- Validation Loss:	0.22347941994667053
# Epoch 65 completed
# 	- Training Accuracy:	0.9363627433776855
# 	- Validation Accuracy:	0.9241904616355896
# 	- Validation Loss:	0.2126297950744629
# Epoch 70 completed
# 	- Training Accuracy:	0.940935492515564
# 	- Validation Accuracy:	0.9299047589302063
# 	- Validation Loss:	0.20188172161579132
# Epoch 75 completed
# 	- Training Accuracy:	0.9400781393051147
# 	- Validation Accuracy:	0.9306666851043701
# 	- Validation Loss:	0.19481898844242096
# Epoch 80 completed
# 	- Training Accuracy:	0.9408402442932129
# 	- Validation Accuracy:	0.9318095445632935
# 	- Validation Loss:	0.19206814467906952
# Epoch 85 completed
# 	- Training Accuracy:	0.9473182559013367
# 	- Validation Accuracy:	0.9337142705917358
# 	- Validation Loss:	0.18661612272262573
# Epoch 90 completed
# 	- Training Accuracy:	0.9466513991355896
# 	- Validation Accuracy:	0.9340952634811401
# 	- Validation Loss:	0.19050286710262299
# Epoch 95 completed
# 	- Training Accuracy:	0.9500809907913208
# 	- Validation Accuracy:	0.935619056224823
# 	- Validation Loss:	0.1829805076122284
# Epoch 100 completed
# 	- Training Accuracy:	0.9488425254821777
# 	- Validation Accuracy:	0.9325714111328125
# 	- Validation Loss:	0.18061476945877075
# Epoch 105 completed
# 	- Training Accuracy:	0.949985682964325
# 	- Validation Accuracy:	0.9333333373069763
# 	- Validation Loss:	0.17956990003585815
# Epoch 110 completed
# 	- Training Accuracy:	0.9533199667930603
# 	- Validation Accuracy:	0.9379047751426697
# 	- Validation Loss:	0.17584311962127686
# Epoch 115 completed
# 	- Training Accuracy:	0.9518910050392151
# 	- Validation Accuracy:	0.9413333535194397
# 	- Validation Loss:	0.18062931299209595
# Epoch 120 completed
# 	- Training Accuracy:	0.9552252888679504
# 	- Validation Accuracy:	0.9409523606300354
# 	- Validation Loss:	0.1750020533800125
# Epoch 125 completed
# 	- Training Accuracy:	0.9516052007675171
# 	- Validation Accuracy:	0.9344761967658997
# 	- Validation Loss:	0.17657214403152466
# Epoch 130 completed
# 	- Training Accuracy:	0.9548442363739014
# 	- Validation Accuracy:	0.9367619156837463
# 	- Validation Loss:	0.17259001731872559
# Epoch 135 completed
# 	- Training Accuracy:	0.9568448066711426
# 	- Validation Accuracy:	0.9432380795478821
# 	- Validation Loss:	0.17439357936382294
# Epoch 140 completed
# 	- Training Accuracy:	0.9557968974113464
# 	- Validation Accuracy:	0.9440000057220459
# 	- Validation Loss:	0.1763893961906433
# Epoch 145 completed
# 	- Training Accuracy:	0.9575116634368896
# 	- Validation Accuracy:	0.942476212978363
# 	- Validation Loss:	0.17166832089424133
# Epoch 150 completed
# 	- Training Accuracy:	0.9566543102264404
# 	- Validation Accuracy:	0.936380922794342
# 	- Validation Loss:	0.1730024665594101
# Epoch 155 completed
# 	- Training Accuracy:	0.9579880237579346
# 	- Validation Accuracy:	0.9428571462631226
# 	- Validation Loss:	0.17403234541416168
# Epoch 160 completed
# 	- Training Accuracy:	0.9587501287460327
# 	- Validation Accuracy:	0.9417142868041992
# 	- Validation Loss:	0.17428424954414368
# Epoch 165 completed
# 	- Training Accuracy:	0.9552252888679504
# 	- Validation Accuracy:	0.9310476183891296
# 	- Validation Loss:	0.1778063178062439
# Epoch 170 completed
# 	- Training Accuracy:	0.9583690762519836
# 	- Validation Accuracy:	0.9348571300506592
# 	- Validation Loss:	0.17426025867462158
# Epoch 175 completed
# 	- Training Accuracy:	0.9597980380058289
# 	- Validation Accuracy:	0.9386666417121887
# 	- Validation Loss:	0.17059452831745148
# Epoch 180 completed
# 	- Training Accuracy:	0.960845947265625
# 	- Validation Accuracy:	0.9401904940605164
# 	- Validation Loss:	0.17023855447769165
# Epoch 185 completed
# 	- Training Accuracy:	0.9606554508209229
# 	- Validation Accuracy:	0.9447619318962097
# 	- Validation Loss:	0.17346569895744324
# Epoch 190 completed
# 	- Training Accuracy:	0.9616080522537231
# 	- Validation Accuracy:	0.9420952200889587
# 	- Validation Loss:	0.17037507891654968
# Epoch 195 completed
# 	- Training Accuracy:	0.960560142993927
# 	- Validation Accuracy:	0.9352381229400635
# 	- Validation Loss:	0.17313723266124725
# Epoch 200 completed
# 	- Training Accuracy:	0.9612269997596741
# 	- Validation Accuracy:	0.9432380795478821
# 	- Validation Loss:	0.17658641934394836
# Epoch 205 completed
# 	- Training Accuracy:	0.961131751537323
# 	- Validation Accuracy:	0.9401904940605164
# 	- Validation Loss:	0.17898185551166534
# Epoch 210 completed
# 	- Training Accuracy:	0.9626560211181641
# 	- Validation Accuracy:	0.9428571462631226
# 	- Validation Loss:	0.17347857356071472
# Epoch 215 completed
# 	- Training Accuracy:	0.9637991786003113
# 	- Validation Accuracy:	0.9413333535194397
# 	- Validation Loss:	0.16975900530815125
# Epoch 220 completed
# 	- Training Accuracy:	0.9631323218345642
# 	- Validation Accuracy:	0.936380922794342
# 	- Validation Loss:	0.17212587594985962
# Epoch 225 completed
# 	- Training Accuracy:	0.9643707871437073
# 	- Validation Accuracy:	0.942476212978363
# 	- Validation Loss:	0.17203010618686676
# Epoch 230 completed
# 	- Training Accuracy:	0.9638944268226624
# 	- Validation Accuracy:	0.9401904940605164
# 	- Validation Loss:	0.17490777373313904
# Epoch 235 completed
# 	- Training Accuracy:	0.9549394845962524
# 	- Validation Accuracy:	0.9276190400123596
# 	- Validation Loss:	0.18702952563762665
# Epoch 240 completed
# 	- Training Accuracy:	0.9616080522537231
# 	- Validation Accuracy:	0.9333333373069763
# 	- Validation Loss:	0.1800033003091812
# Epoch 245 completed
# 	- Training Accuracy:	0.9634181261062622
# 	- Validation Accuracy:	0.936380922794342
# 	- Validation Loss:	0.1759740114212036
# Epoch 250 completed
# 	- Training Accuracy:	0.9655139446258545
# 	- Validation Accuracy:	0.9359999895095825
# 	- Validation Loss:	0.17578619718551636
# Epoch 255 completed
# 	- Training Accuracy:	0.9676098227500916
# 	- Validation Accuracy:	0.9375237822532654
# 	- Validation Loss:	0.17487746477127075
# Epoch 260 completed
# 	- Training Accuracy:	0.9672287106513977
# 	- Validation Accuracy:	0.9409523606300354
# 	- Validation Loss:	0.17393101751804352
# Epoch 265 completed
# 	- Training Accuracy:	0.9679908752441406
# 	- Validation Accuracy:	0.939047634601593
# 	- Validation Loss:	0.1757795661687851
# Epoch 270 completed
# 	- Training Accuracy:	0.9678955674171448
# 	- Validation Accuracy:	0.939047634601593
# 	- Validation Loss:	0.1778382658958435
# Epoch 275 completed
# 	- Training Accuracy:	0.9686577320098877
# 	- Validation Accuracy:	0.9398095011711121
# 	- Validation Loss:	0.1764674037694931
# Epoch 280 completed
# 	- Training Accuracy:	0.9685624241828918
# 	- Validation Accuracy:	0.9371428489685059
# 	- Validation Loss:	0.17973695695400238
# Epoch 285 completed
# 	- Training Accuracy:	0.9624654650688171
# 	- Validation Accuracy:	0.9299047589302063
# 	- Validation Loss:	0.18958482146263123
# Epoch 290 completed
# 	- Training Accuracy:	0.9687529802322388
# 	- Validation Accuracy:	0.9409523606300354
# 	- Validation Loss:	0.17899225652217865
# Epoch 295 completed
# 	- Training Accuracy:	0.9676098227500916
# 	- Validation Accuracy:	0.9340952634811401
# 	- Validation Loss:	0.1815863698720932

# %%
import matplotlib.pyplot as plt
plt.plot(ep, acc)
plt.xlabel('epochs')
plt.ylabel('accuracy')
# Out:
# Text(0, 0.5, 'accuracy')

# %%
plt.rc('xtick',labelsize=17)
plt.rc('ytick',labelsize=17)
fig, ax = plt.subplots(figsize=(11,8))
ax.plot(ep, acc,marker = "o",linewidth=3,markersize=10)
ax.set_xlabel("Numero de Iteraciones",fontsize=17)
ax.set_ylabel("Precision",fontsize=17)
ax.set_title("Grafico de aprendizaje (Precision vs no. iteraciones) ",fontsize=16)
plt.grid()
plt.savefig('Accuracy_1e-3.jpeg')

# %%
plt.rc('xtick',labelsize=17)
plt.rc('ytick',labelsize=17)
fig, ax = plt.subplots(figsize=(11,8))
ax.plot(ep, loss,marker = "o",linewidth=3,markersize=10)
ax.set_xlabel("Numero de Iteraciones",fontsize=17)
ax.set_ylabel("Error",fontsize=17)
ax.set_title("Grafico de aprendizaje (Error vs no. iteraciones) ",fontsize=16)
plt.grid()
plt.savefig('Loss_1e-3.jpeg')
